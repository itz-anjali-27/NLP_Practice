# %%
'''TF-IDF = Term Frequency – Inverse Document Frequency
It is an improved version of Bag of Words.
Instead of just counting words,
it:
1.Increases weight for important words
2.Decreases weight for common words'''

# %% [markdown]
# ### Import Library

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "I love NLP",
    "I love machine learning",
    "NLP is fun"
]

# %% [markdown]
# ### Create TF-IDF Vectorizer

# %%
vectorizer = TfidfVectorizer()

# %% [markdown]
# ### Fit and Transform

# %%
X = vectorizer.fit_transform(documents)

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['fun' 'is' 'learning' 'love' 'machine' 'nlp']

# %% [markdown]
# ### View TF-IDF Matrix

# %%
print(X.toarray())
# Out:
# [[0.         0.         0.         0.70710678 0.         0.70710678]
#  [0.         0.         0.62276601 0.4736296  0.62276601 0.        ]
#  [0.62276601 0.62276601 0.         0.         0.         0.4736296 ]]

# %% [markdown]
# ## Important Parameters

# %% [markdown]
# ### 1. Remove Stopwords

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %% [markdown]
# ### 2. Limit Vocabulary

# %%
vectorizer = TfidfVectorizer(max_features=5)

# %% [markdown]
# ### 3. n-grams

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2))
